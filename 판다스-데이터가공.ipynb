# %%
#데이터 취득 및 가공

import numpy as np
import pandas as pd

#데이터 읽어 들이기 _ GAP_5year.csv(탭으로구분)
gap = pd.read_csv('c:\Java\GAP_5year.tsv', sep='\t')
gap.head() #위에서 5줄
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gap.tail() #아래에서 5줄
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
gap.info() #데이터 구조
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
gap.describe() #기술통계 요약
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
#데이터 조회
#한국 데이터 조회
kor = gap.query('country=="Korea, Rep."')
kor
# Out:
#          country continent  year  lifeExp       pop     gdpPercap
# 840  Korea, Rep.      Asia  1952   47.453  20947571   1030.592226
# 841  Korea, Rep.      Asia  1957   52.681  22611552   1487.593537
# 842  Korea, Rep.      Asia  1962   55.292  26420307   1536.344387
# 843  Korea, Rep.      Asia  1967   57.716  30131000   2029.228142
# 844  Korea, Rep.      Asia  1972   62.612  33505000   3030.876650
# 845  Korea, Rep.      Asia  1977   64.766  36436000   4657.221020
# 846  Korea, Rep.      Asia  1982   67.123  39326000   5622.942464
# 847  Korea, Rep.      Asia  1987   69.810  41622000   8533.088805
# 848  Korea, Rep.      Asia  1992   72.244  43805450  12104.278720
# 849  Korea, Rep.      Asia  1997   74.647  46173816  15993.527960
# 850  Korea, Rep.      Asia  2002   77.045  47969150  19233.988180
# 851  Korea, Rep.      Asia  2007   78.623  49044790  23348.139730

# %%
kor = gap.query('country=="Korea, Rep." & year == 2007')
kor
#R로는 dplyr - filter함수 사용 
#filter(gap, country=='' & year == 2007)
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 851  Korea, Rep.      Asia  2007   78.623  49044790  23348.13973

# %%
#정렬해서 출력
#year, country 순으로 정렬 후 출력
sort = gap.sort_values(by=['year', 'country'])
sort.head()
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 24      Algeria    Africa  1952   43.077   9279525  2449.008185
# 36       Angola    Africa  1952   30.015   4232095  3520.610273
# 48    Argentina  Americas  1952   62.485  17876956  5911.315053

# %%
#부분열 선택하기
#인구수, 1인당GDP를 출력
partcol = gap[['pop', 'gdpPercap']]
partcol

#R dplyr - gap %>%select(pop, gdpPercap)
# Out:
#            pop    gdpPercap
# 0      8425333   779.445314
# 1      9240934   820.853030
# 2     10267083   853.100710
# 3     11537966   836.197138
# 4     13079460   739.981106
# 5     14880372   786.113360
# 6     12881816   978.011439
# 7     13867957   852.395945
# 8     16317921   649.341395
# 9     22227415   635.341351
# 10    25268405   726.734055
# 11    31889923   974.580338
# 12     1282697  1601.056136
# 13     1476505  1942.284244
# 14     1728137  2312.888958
# 15     1984060  2760.196931
# 16     2263554  3313.422188
# 17     2509048  3533.003910
# 18     2780097  3630.880722
# 19     3075321  3738.932735
# 20     3326498  2497.437901
# 21     3428038  3193.054604
# 22     3508512  4604.211737
# 23     3600523  5937.029526
# 24     9279525  2449.008185
# 25    10270856  3013.976023
# 26    11000948  2550.816880
# 27    12760499  3246.991771
# 28    14760787  4182.663766
# 29    17152804  4910.416756
# ...        ...          ...
# 1674   9657618  1977.557010
# ...

# %%
#특정열 추가하기
#총GDP(gdp) : POP * gdpPercap
#GDP증가율(gdp_ratio) : lifeExp / gdpPercap
#GDP증가비(%)(gdp_perc) : gdp_ratio * 100
gap['gdp'] = gap['pop']*gap['gdpPercap']
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap           gdp
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314  6.567086e+09
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030  7.585449e+09
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710  8.758856e+09
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138  9.648014e+09
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106  9.678553e+09

# %%
gap['gdp_ratio'] = gap['lifeExp'] / gap['gdpPercap']
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap           gdp  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314  6.567086e+09
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030  7.585449e+09
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710  8.758856e+09
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138  9.648014e+09
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106  9.678553e+09
#
#    gap_ratio  gdp_ratio
# 0   0.036951   0.036951
# 1   0.036952   0.036952
# 2   0.037507   0.037507
# 3   0.040684   0.040684
# 4   0.048769   0.048769

# %%
#GDP증가비(%)(gdp_perc) : gdp_ratio * 100
gap['gdp_perc'] = gap['gdp_ratio']*100
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap           gdp  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314  6.567086e+09
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030  7.585449e+09
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710  8.758856e+09
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138  9.648014e+09
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106  9.678553e+09
#
#    gap_ratio  gdp_ratio  gdp_perc
# 0   0.036951   0.036951  3.695064
# 1   0.036952   0.036952  3.695180
# 2   0.037507   0.037507  3.750671
# 3   0.040684   0.040684  4.068419
# 4   0.048769   0.048769  4.876881

# %%
#통계량 계산하기
gap.aggregate(['mean', 'median', 'mode'])
gap.agg(['sum', 'min', 'max'])
# Out:
#                                                country  \
# sum  AfghanistanAfghanistanAfghanistanAfghanistanAf...
# min                                        Afghanistan
# max                                           Zimbabwe
#
#                                              continent     year       lifeExp  \
# sum  AsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAs...  3373068  101344.44468
# min                                             Africa     1952      23.59900
# max                                            Oceania     2007      82.60300
#
#              pop     gdpPercap           gdp  gap_ratio  gdp_ratio  \
# sum  50440465801  1.229492e+07  3.183235e+14  46.888957  46.888957
# min        60011  2.411659e+02  5.278469e+07   0.000511   0.000511
# max   1318683096  1.135231e+05  1.293446e+13   0.186453   0.186453
#
#         gdp_perc
# sum  4688.895673
# min     0.051120
# max    18.645258

# %%
#표본 추출을 위한 샘플링 : sample()
np.random.seed(9564)
print(gap.sample(n=10))
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 1287              Rwanda    Africa  1967   44.100   3451079    510.963714
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 1207                Peru  Americas  1987   64.134  20195924   6360.943444
# 1076               Nepal      Asia  1992   55.727  20326209    897.740360
# 1697            Zimbabwe    Africa  1977   57.674   6642107    685.587682
# 1663  West Bank and Gaza      Asia  1987   67.046   1691210   5107.197384
# 1487         Switzerland    Europe  2007   81.701   7554661  37506.419070
# 710            Indonesia      Asia  1962   42.518  99028000    849.289770
# 240               Canada  Americas  1952   68.750  14785584  11367.161120
# 1196            Paraguay  Americas  1992   68.225   4483945   4196.411078
#
#                gdp  gap_ratio  gdp_ratio  gdp_perc
# 1287  1.763376e+09   0.086307   0.086307  8.630750
# 11    3.107929e+10   0.044971   0.044971  4.497115
# ...

# %%
#중복제거후 모든항목 출력
print(gap.country)
print(gap.country.unique())

print(gap.year)
print(gap.year.unique())

print(gap.drop_duplicates(['country', 'year']).head())
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Algeria
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 1674    Yemen, Rep.
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1680         Zambia
# 1681         Zambia
# 1682         Zambia
# 1683         Zambia
# 1684         Zambia
# 1685         Zambia
# 1686         Zambia
# 1687         Zambia
# ...

# %%
#group by 연산
#2007년 기준 대륙별 생활지수 평균값 분석
lifeExp2007 = gap.query('year==2007').groupby('continent').agg({'lifeExp':'mean'})
lifeExp2007
# Out:
#              lifeExp
# continent
# Africa     54.806038
# Americas   73.608120
# Asia       70.728485
# Europe     77.648600
# Oceania    80.719500
